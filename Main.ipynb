# %%
import numpy as np
import pandas as pd
import os
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer 
nltk.download("vader_lexicon")
# Out:
# [nltk_data] Error loading vader_lexicon: <urlopen error [WinError
# [nltk_data]     10054] An existing connection was forcibly closed by
# [nltk_data]     the remote host>
# False

# %%
df = pd.read_csv("Updated_Flipkart.csv", encoding = 'unicode_escape')

# %%
df.head()
# Out:
#                                          ProductName     Price  Rate  \
# 0  MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     5
# 1  MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     4
# 2  MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     5
# 3  MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     5
# 4  MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     5
#
#                  Review                                            Summary
# 0             Wonderful  The best poduct that i bought from flifkart it...
# 1  Good quality product  cooler is big and wide . maharaja brand trust ...
# 2               Awesome  It is one of the best air coolers at reasonabl...
# 3             Excellent  Awesome Air coolerI was looking for a cooler u...
# 4         Great product  Purchased after a lot of discussions and revie...

# %%
sentiments = SentimentIntensityAnalyzer()
df["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in df["Summary"]]
df["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in df["Summary"]]
df["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in df["Summary"]]
df["Compound"] = [sentiments.polarity_scores(i)["compound"] for i in df["Summary"]]
# data.head()
score = df["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
df["Sentiment"] = sentiment
# df.head()

# %%
df.drop(df.columns[[5, 6, 7, 8]], axis=1, inplace=True)
df
# Out:
#                                            ProductName     Price  Rate  \
# 0    MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     5
# 1    MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     4
# 2    MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     5
# 3    MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     5
# 4    MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     5
# ..                                                 ...       ...   ...
# 775  MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     3
# 776  MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     5
# 777  MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     4
# 778  MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     5
# 779  MAHARAJA WHITELINE 65 L Desert Air Cooler?Ø?Ø(...  Ä??7,999     5
#
#                    Review                                            Summary  \
# 0               Wonderful  The best poduct that i bought from flifkart it...
# 1    Good quality product  cooler is big and wide . maharaja brand trust ...
# 2                 Awesome  It is one of the best air coolers at reasonabl...
# 3               Excellent  Awesome Air coolerI was looking for a cooler u...
# 4           Great product  Purchased after a lot of discussions and revie...
# ..                    ...                                                ...
# 775             Just okay  Air Flow is not sufficient. Speed of Fan is lo...
# 776   Best in the market!                                               Nice
# 777       Value-for-money                      Nice product on time delivery
# 778             Wonderful                                      Super cooling
# 779             Hated it!                                    Awesome product
#
#     Sentiment
# 0    Positive
# 1    Positive
# 2    Positive
# 3    Positive
# 4    Positive
# ..        ...
# 775  Positive
# 776  Positive
# 777  Positive
# 778  Positive
# 779  Positive
#
# [780 rows x 6 columns]

# %%
df["Sentiment"].unique()
# Out:
# array(['Positive', 'Negative', 'Neutral'], dtype=object)

# %%
df.to_csv("Sentiment.csv")
